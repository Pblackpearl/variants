# %%
import numpy as np
import pandas as pd
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_variants=pd.read_csv('variants.csv')
df_variants.head()
# Out:
#   State             Type  B.1.1.7 Variant   P.1 Variant   B.1.351 Variant
# 0    AK  Variant B.1.1.7                 6             6                 1
# 1    AK      Variant P.1                 6             6                 1
# 2    AK  Variant B.1.351                 6             6                 1
# 3    AL  Variant B.1.1.7               186             0                 2
# 4    AL      Variant P.1               186             0                 2

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')

# %%
df_variants.plot(kind='bar', figsize=(30,15))

plt.xlabel('B.1.1.7')
plt.xlabel('P.1')
plt.xlabel('B.1.351')
plt.ylabel('State')
plt.title('Variant Cases in the U.S.')
          
plt.show()
